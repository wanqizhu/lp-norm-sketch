# %%
import numpy as np
import math

# %%
# %lprun
def lp_norm_sketch(A, k, n, _lambda, _epsilon, trials=1):
    # compute the number of counters we need
    s1 = math.ceil(8*k*n**(1-1/k)/(_lambda**2))
    s2 = math.ceil(2*math.log(1/_epsilon))
    
    X = np.zeros((s2, s1, trials))  # the random element we care about
    r = np.zeros((s2, s1, trials))  # stores the frequency count
    
    for cnt, a in enumerate(A):
        # since we don't know m in advance, we
        # update X and r as we go
        # when we encounter the m-th element, we update w.p. 1/m
        to_change = np.random.rand(s2, s1, trials) < 1/(1+cnt)
        X[to_change] = a
        r[to_change] = 0  # reset counter as needed
        r[X == a] += 1
    
    return np.median(np.mean(cnt*(r**k - (r-1)**k), axis=1), axis=0)
# Out:
# UsageError: Line magic function `%lprun` not found.

# %%
a = np.random.rand(4, 3, 10)
print(np.sum(a, axis=1).shape)
print(np.median(np.sum(a, axis=1), axis=0).shape)

# %%
n = 50
A = np.random.randint(n, size=(1000, ))
A
# Out:
# array([14,  6, 46,  0, 49, 16, 10, 21, 24, 30, 39, 14, 24, 19, 44, 36, 32,
#        11, 27, 42, 23,  5, 23,  6,  4, 44, 44, 21, 10, 37, 26, 42, 21, 11,
#        20, 34, 31, 20, 29, 32,  4, 21, 25, 31,  3, 40, 32,  2, 43, 22,  1,
#         6,  4, 22, 14, 40,  5, 41, 20,  1, 26, 12, 30,  6, 12,  1, 45, 32,
#        11, 18,  7, 26, 30, 17,  2, 34, 25, 12, 46,  2,  0,  7, 41,  3, 26,
#        24, 48, 18, 13, 34, 28, 16, 41, 40, 11, 37,  6, 25, 39, 33, 44, 30,
#        45, 34, 38, 36, 11, 10,  8, 46, 33, 17, 27,  8,  2, 10, 19, 21, 35,
#        27, 26, 16, 48, 16, 23, 19, 21,  1, 19, 14, 32, 22, 38, 19, 41, 24,
#        37, 32, 11, 18, 36, 45, 18, 23, 15, 43, 36, 39, 47, 29, 30, 26, 36,
#        14, 44,  7, 32, 46,  9, 35, 47, 10, 42, 18,  6, 13, 16, 23, 27, 17,
#        37, 42,  6, 28,  2, 39, 28, 15, 31, 25, 21, 41, 11, 43, 26, 41, 48,
#        21, 31, 29,  4, 20, 26, 26, 22, 19, 45, 34, 47, 26, 20,  2,  4, 17,
#         4, 17, 20, 31, 43, 38, 13, 20, 36, 34, 20,  5, 40, 16, 25,  9, 23,
#        23, 20, 13,  6, 42, 29, 17, 46,  1,  1,  1, 46, 42, 39, 35, 39, 48,
#        22, 22, 34,  0, 26, 11, 45, 46, 48, 10, 10, 16, 35, 14, 42, 12, 27,
#         2, 18,  1, 46,  1, 39, 36,  2, 36, 14, 10, 39,  2, 21, 48, 27, 41,
#        38,  6, 30, 37, 24, 10, 49, 44,  7, 41, 43, 41,  8, 43, 34, 39, 38,
#        20, 49, 41, 16,  5, 36, 22,  6,  0, 35,  2, 29,  3, 45, 43, 44, 28,
#        49, 19, 10, 20, 47, 16, 20, 19, 20, 34, 48, 32, 39, 23, 16,  0, 34,
#         8, 18, 29, 23, 10,  2, 24, 38, 34, 42, 30, 13, 42, 49, 30, 14, 49,
#        16, 48, 21, 28, 28, 38, 27, 45, 46,  6, 29,  3,  3,  6, 36, 20, 34,
#        42, 11, 22,  9, 41, 30, 36,  8, 28, 39,  9, 15, 14,  0, 43, 14, 34,
#        21, 43, 43, 46, 24, 16, 42, 28,  8, 48, 36, 27, 47, 10, 48, 17, 44,
#        32, 12, 49, 18, 27, 23, 44,  0, 12, 41, 15, 33, 26, 43, 36, 23,  2,
#         3,  4,  6, 44,  4, 41, 25, 26, 37, 16, 14, 10, 41,  7, 35, 19, 32,
#        15, 23, 11, 31, 39,  4, 26, 18,  5, 37, 49, 19, 38, 18,  3, 44, 37,
#        24, 14, 35, 16, 27, 49, 40, 20, 17, 23, 23, 18, 28,  4, 48, 11,  2,
#        49, 41, 43, 32, 26, 47, 26,  7, 20, 10, 45, 17, 12, 42, 41, 31, 39,
#        19, 47,  6, 14, 26,  9, 49, 37, 13, 19, 36, 44, 10, 29, 19, 12, 33,
#        49, 15,  9, 25, 37, 30, 40, 23, 21,  8, 21, 28, 46, 36, 16, 43, 45,
#         7, 36,  9, 28,  8, 41, 35, 31, 40, 31,  2, 38, 46, 17,  1, 13,  2,
#        22, 46, 32, 28, 33,  1,  1, 44, 28,  2, 21, 34, 23, 48,  9, 39, 12,
#        10, 28, 39, 16, 31, 40, 25, 28, 18, 48,  2, 21,  0, 36, 35,  3, 15,
#        41, 33, 23, 28,  5, 16, 30, 19,  8, 42, 35, 15, 10,  1, 40, 38,  5,
#         7, 36, 30, 14, 14,  5,  4, 46,  6, 47, 25,  5,  3, 37, 37, 21, 24,
#        29,  6, 18, 16, 10, 19, 39,  2,  2, 33,  2, 36, 20, 46, 21, 25, 25,
#        21,  0, 35,  8, 42, 18, 34, 37,  1, 37, 45, 34, 35,  6, 28,  6, 13,
#        44, 24,  3, 34, 11, 41, 28, 47, 48, 14, 29, 46, 13, 18, 46, 39,  6,
#        45, 29, 14, 18, 34, 49, 49, 25, 30, 35, 18, 16, 41, 25, 22, 30, 24,
#        39, 47, 23, 49, 29, 12, 24, 10, 45, 15, 31,  5, 10, 46, 48, 32, 28,
#         2, 30, 18, 18, 30, 32, 38, 36, 45, 39, 47, 34, 10, 21, 15, 19,  9,
#        26, 39, 21, 23, 43,  8, 40, 43, 25, 12,  1, 44, 23, 32, 39, 45, 22,
#        21,  1, 42,  8, 48,  4,  1, 34, 29, 24, 46,  8, 49, 31,  8, 25, 19,
#        37, 42, 20, 18, 29, 30, 44, 31, 13, 26, 19, 39, 14, 28, 18, 47,  0,
#        36,  3, 12,  5, 21,  2, 20, 33, 42, 46, 33,  6, 45, 27, 35,  3,  0,
#        22, 24, 10, 10, 37, 19, 33, 17, 27,  4, 13, 27, 45, 30, 29,  2, 22,
#        37, 41,  7, 25, 39,  0, 46,  3, 34, 29, 14, 19, 48,  9, 31, 10, 17,
#         7, 49,  7, 37,  0, 14, 24, 36, 28, 12, 45, 19, 48, 13,  3, 46, 17,
#         5, 15, 35, 32, 14, 11,  0, 28,  6, 42,  2, 42, 40,  3, 30, 35,  1,
#        42, 25,  5, 46, 47, 40, 38, 27, 13, 44, 29, 31, 36, 30, 22,  7, 22,
#         7, 27, 15, 34, 21,  7, 16, 11, 14, 37,  3, 42, 26, 21, 15, 47, 34,
#        15, 45, 27, 25, 30, 24, 21,  3, 28, 47,  4, 44, 24,  3, 34, 36, 49,
#        17,  9, 24, 12, 30, 35, 32,  5, 35,  5, 43,  7, 34, 25, 31, 41,  1,
#        44,  3, 37, 25,  8,  5, 29,  2,  2,  8, 13, 20, 19, 13, 13,  2, 29,
#        22, 31, 46, 30, 49,  8, 49, 47, 16,  3, 20, 18, 43, 28, 13, 41, 23,
#        35,  7, 28, 28, 42,  5, 23,  8,  7, 21,  4,  6, 28, 42, 30, 36, 37,
#        12, 30, 42, 22, 11, 43, 46,  7, 10, 25,  5,  8, 16, 39, 41, 24,  5,
#        24, 30, 37, 26, 44, 42, 13, 45, 16, 17, 27, 11, 36, 41, 25, 49, 26,
#        24, 11, 46, 11, 26,  9, 18,  8, 18, 39, 12,  4, 22, 37])

# %%
A = np.arange(1000)

# %%
uniq, cnts = np.unique(A, return_counts=True)
k = 2
np.sum(cnts**k)
# Out:
# 1000

# %%
lp_norm_sketch(A, k, n, 0.1, 0.1, 10)
# Out:
# 7.43 s ± 178 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
